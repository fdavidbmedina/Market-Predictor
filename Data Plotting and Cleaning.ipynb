# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "./dataset/csv/Ak-47SlateMW.csv"

# display dimension

df = pd.read_csv(path)

df.plot(kind = 'line' , x ='Sold Hours Ago', y = 'Price', c = 'blue')
# Out:
# <AxesSubplot:xlabel='Sold Hours Ago'>
